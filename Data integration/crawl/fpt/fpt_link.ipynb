# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
browser = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2} # Tắt thông báo Chrome
browser.add_experimental_option("prefs",prefs)
browser = webdriver.Chrome(chrome_options=browser, executable_path=r'D:\Tai Lieu\HUST-Study\20202\Tích hợp dl\nguyen\chromedriver.exe')
browser.get('https://fptshop.com.vn/dien-thoai'
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:4: DeprecationWarning: use options instead of chrome_options
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\AppData\Local\Programs\Python\Python37\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# ...

# %%
more = True
while more:
    try:
        moreproduct = browser.find_element_by_class_name ('cdt-product--loadmore')
        moreproduct.click()
    except:
        more = False

# %%
items = browser.find_elements_by_xpath('//div[@class="cdt-product-wrapper m-b-20"]/*/div[2]/h3/a')

links = []
i=0
for item in items:
    i+=1

    name = item.text
    link = item.get_attribute('href')
    print(name, link)

    links.append(link)

print(i)
# Out:
# ng Galaxy A51 https://fptshop.com.vn/dien-thoai/samsung-galaxy-a51
# Samsung Galaxy A21s https://fptshop.com.vn/dien-thoai/samsung-galaxy-a21s
# Vivo Y50 8GB - 128GB https://fptshop.com.vn/dien-thoai/vivo-y50
# Vivo Y20s 6GB - 128GB https://fptshop.com.vn/dien-thoai/vivo-y20s-6gb-128gb
# iPhone XR 64GB https://fptshop.com.vn/dien-thoai/iphone-xr-64gb
# Nokia 5.4 4GB -128GB https://fptshop.com.vn/dien-thoai/nokia-5-4
# Samsung Galaxy Z Fold2 5G https://fptshop.com.vn/dien-thoai/samsung-galaxy-z-fold-2-5g
# iPhone 11 Pro 512GB https://fptshop.com.vn/dien-thoai/iphone-11-pro-512gb
# Samsung Galaxy S21 Ultra 128GB https://fptshop.com.vn/dien-thoai/samsung-galaxy-s21-ultra?dung-luong=128gb
# Samsung Galaxy S20 Ultra https://fptshop.com.vn/dien-thoai/samsung-galaxy-s20-ultra
# iPhone 12 Pro 128GB https://fptshop.com.vn/dien-thoai/iphone-12-pro?dung-luong=128gb
# Samsung Galaxy Note 20 Ultra 5G https://fptshop.com.vn/dien-thoai/samsung-galaxy-note-20-ultra-5g
# ...

# %%
for i in range(len(links)):
    print(i+1)
    browser.get(links[i])
    
    try:
        L = browser.find_elements_by_xpath('//div[@class="st-select"]/*[position()>1]')
        for link in L:
            link = link.get_attribute('href')

            print(link)
            links.append(link)
    except:
        break
# Out:
# 1
# 2
# https://fptshop.com.vn/dien-thoai/oppo-reno5?ho-tro-mang=5g
# 3
# https://fptshop.com.vn/dien-thoai/iphone-11-128gb
# https://fptshop.com.vn/dien-thoai/iphone-11-256gb
# 4
# https://fptshop.com.vn/dien-thoai/iphone-12?dung-luong=128gb
# https://fptshop.com.vn/dien-thoai/iphone-12?dung-luong=256gb
# 5
# 6
# 7
# 8
# https://fptshop.com.vn/dien-thoai/iphone-12-pro-max?dung-luong=256gb
# https://fptshop.com.vn/dien-thoai/iphone-12-pro-max?dung-luong=512gb
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-s21-plus?dung-luong=256gb
# 16
# 17
# 18
# https://fptshop.com.vn/dien-thoai/xiaomi-redmi-note-10?dung-luong=4gb-64gb
# 19
# 20
# https://fptshop.com.vn/dien-thoai/vsmart-joy-3-2gb-32gb
# 21
# 22
# 23
# https://fptshop.com.vn/dien-thoai/xiaomi-mi-10t-pro-5g?dung-luong=128gb
# 24
# 25
# 26
# 27
# 28
# 29
# https://fptshop.com.vn/dien-thoai/iphone-xr-128gb
# https://fptshop.com.vn/dien-thoai/iphone-xr-256gb
# 30
# 31
# 32
# ...

# %%
import csv

with open('fpt_link_1.csv', mode='a', encoding='utf-8', newline='') as file:
    for link in links:
        print(link)
        writer = csv.writer(file)
        writer.writerow([link])
file.close()

import pandas as pd

df = pd.read_csv('fpt_link_1.csv', header=None)
df.columns = ['link']
df.to_csv('fpt_link_1.csv', index = False)
# Out:
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-z-flip
# https://fptshop.com.vn/dien-thoai/oppo-reno5?ho-tro-mang=4g
# https://fptshop.com.vn/dien-thoai/iphone-11-64gb
# https://fptshop.com.vn/dien-thoai/iphone-12?dung-luong=64gb
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-s20-plus
# https://fptshop.com.vn/dien-thoai/xiaomi-mi-10t-lite-5g
# https://fptshop.com.vn/dien-thoai/xiaomi-redmi-note-9
# https://fptshop.com.vn/dien-thoai/iphone-12-pro-max?dung-luong=128gb
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-a72
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-a52
# https://fptshop.com.vn/dien-thoai/oppo-a92
# https://fptshop.com.vn/dien-thoai/oppo-a73
# https://fptshop.com.vn/dien-thoai/vivo-y20
# https://fptshop.com.vn/dien-thoai/xiaomi-redmi-9-64gb
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-s21-plus?dung-luong=128gb
# https://fptshop.com.vn/dien-thoai/samsung-galaxy-note-20-ultra
# https://fptshop.com.vn/dien-thoai/vivo-y51
# ...
